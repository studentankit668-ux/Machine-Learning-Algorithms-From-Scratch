# %% [markdown]
# <a href="https://colab.research.google.com/github/studentankit668-ux/Machine-Learning-Algorithms-From-Scratch/blob/main/Linear_Regression_From_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !https://github.com/studentankit668-ux/Machine-Learning-Algorithms-From-Scratch.git
# Out:
# /bin/bash: line 1: https://github.com/studentankit668-ux/Machine-Learning-Algorithms-From-Scratch.git: No such file or directory
